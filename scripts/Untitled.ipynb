# %%
filelist <-  read.table("/home/anandgavai/Sherlock3/cluster-analysis/data/pentax/filelist.txt",sep=" ")

# %%
edgeList_ncc <- read.table("/home/anandgavai/Sherlock3/cluster-analysis/data/pentax/edgelist-pentax-ncc.txt",sep=" ")
edgeList_pce <- read.table("/home/anandgavai/Sherlock3/cluster-analysis/data/pentax/edgelist-pentax-pce.txt",sep=" ")
edgeList_pce0 <- read.table("/home/anandgavai/Sherlock3/cluster-analysis/data/pentax/edgelist-pentax-pce0.txt",sep=" ")

# %%
ncc<-edgeList_ncc[,3]
pce<-edgeList_pce[,3]
pce0<-edgeList_pce0[,3]

# %%
summary (ncc)
summary (pce)
summary (pce0)
# Out:
#       Min.    1st Qu.     Median       Mean    3rd Qu.       Max.
# -7.633e-03 -6.966e-05  2.694e-04  1.035e-03  7.996e-04  1.111e-01
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#     0.00     0.23     1.15    49.07     5.22 97780.00
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
#     23.97     28.65     30.36     95.28     33.29 288000.00

# %%
ncc<-edgeList_ncc[,3]
plot(density(ncc))
plot(density(na.omit(sqrt(ncc))))
plot(density(na.omit(log(ncc))))
# Out:
# Warning message:
# In sqrt(ncc): NaNs produced
# Plot with title “density.default(x = ncc)”
# Warning message:
# In log(ncc): NaNs produced
# Plot with title “density.default(x = na.omit(sqrt(ncc)))”
# Plot with title “density.default(x = na.omit(log(ncc)))”

# %%
pce<-edgeList_pce[,3]
plot(density(pce))
plot(density(sqrt(pce)))
plot(density(log(pce)),xlim=c(-20,20))
# Out:
# Plot with title “density.default(x = pce)”
# Plot with title “density.default(x = sqrt(pce))”
# Plot with title “density.default(x = log(pce))”

# %%
pce0<-edgeList_pce0[,3]
plot(density(pce0))
plot(density(sqrt(pce0)))
plot(density(log(pce0)))
# Out:
# Plot with title “density.default(x = pce0)”
# Plot with title “density.default(x = sqrt(pce0))”
# Plot with title “density.default(x = log(pce0))”

# %%
pce_log<-log(pce)

#scaling between 0 and 1 
nV<-(pce_log-min(pce_log))/(max(pce_log)-min(pce_log))

idx<-which(nV < 0.4)
nV[idx]<-0.4


idx2<-which(nV>0.9)
nV[idx2]<-0.9


x <- ((nV/0.35) - (0.4/0.35))^2
x <- x/2

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”
